# %%
# script for plotting the PSDs before and after the train removal routine
import os
import re
import math
import pickle
import datetime
import numpy as np
import scipy.signal as sp
import matplotlib.pyplot as plt

from obspy import read_inventory, UTCDateTime
from obspy.clients.filesystem.sds import Client
from modules import trainMaskMod

stnName = 'TEUV'
compName = 'BHZ'

f = '/data/gravwav/koley/PSDHistBoreholes/PSDLenTrainRemove/TEUV_BHZ_pair_hist_trainmasked.pkl'
trainMaskMod.plotPairResults(f, titlePrefix=stnName + ' ' + compName)
